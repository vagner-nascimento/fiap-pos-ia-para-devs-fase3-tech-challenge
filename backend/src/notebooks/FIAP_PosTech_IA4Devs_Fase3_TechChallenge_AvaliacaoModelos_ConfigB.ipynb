# %% [markdown]
# # Avaliação e Validação de Modelos — FIAP Pós Tech IA para Devs (Fase 3)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vagner-nascimento/fiap-pos-ia-para-devs-fase3-tech-challenge/blob/main/backend/src/notebooks/FIAP_PosTech_IA4Devs_Fase3_TechChallenge_AvaliacaoModelos.ipynb)
#
# ## Visão Geral do Notebook
# Este notebook é dedicado à **avaliação formal e análise quantitativa e qualitativa** do modelo "fine-tunado" para o assistente médico hospitalar (`hospital-helper`), atendendo ao requisito do edital do Tech Challenge Fase 3.
#
# ### Estágios dos Modelos Avaliados:
# 1. **Modelo Base Fundacional:** `Qwen/Qwen2.5-1.5B-Instruct` (sem fine-tuning no domínio hospitalar brasileiro).
# 2. **Fine-Tuned v1.0 (Tag `v1.0`):** Treinado no notebook `v1` com 188 steps de aquecimento.
# 3. **Fine-Tuned v2.0 (Tag `v2.0` - Produção):** Treinado a partir do notebook `v2` (evoluído até o `v4`) com checkpoints contínuos e consolidados no Hugging Face Hub.
#
# ### Métricas Computadas:
# - **ROUGE-1, ROUGE-2 e ROUGE-L** (precisão, recall e f-measure)
# - **BLEU-4** (precisão de n-gramas em relação às respostas de referência clínica)
# - **Latência e Throughput** (tempo de inferência e tokens por segundo na GPU T4)
# - **Análise Qualitativa Lado a Lado (*Side-by-Side*):** Comparação clínica de condutas de emergência e ativação de guardrails assistenciais.

# %% [markdown]
# ## 1. Verificação do Ambiente de Execução e GPU

# %%
# !nvidia-smi

import torch
print(f"CUDA disponível: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Dispositivo GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM Total: {torch.cuda.get_device_properties(0).total_memory / (1024**3):.2f} GB")
    print(f"Suporte a bfloat16: {torch.cuda.is_bf16_supported()}")
# Out:
# Sun Sep  6 14:48:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0             30W /   70W |    6085MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2824      C   /usr/bin/python3                       6082MiB |
# +-----------------------------------------------------------------------------------------+
# CUDA disponível: True
# Dispositivo GPU: Tesla T4
# VRAM Total: 14.56 GB
# Suporte a bfloat16: True

# %% [markdown]
# ## 2. Instalação das Dependências de Avaliação

# %%
# Instalação silenciosa de pacotes para inferência e cálculo de métricas NLP
# !pip install -q transformers accelerate evaluate rouge-score sacrebleu tabulate matplotlib sentencepiece

# %% [markdown]
# ## 3. Configuração de Parâmetros e Seleção de Tags no Hugging Face

# %% [markdown]
# ### Teste com 3 configurações diferentes:
#
# ---
#
# Configuração A — Greedy Determinística (Padrão de Precisão Clínica)
# ```
# TEMPERATURE = 0.0
# DO_SAMPLE = False
# MAX_NEW_TOKENS = 300
# REPETITION_PENALTY = 1.05
# ```
#
# ---
#
# Configuração B — Baixa Entropia com Amostragem Suave (Mais Natural)
# ```
# TEMPERATURE = 0.15
# TOP_P = 0.90
# DO_SAMPLE = True
# MAX_NEW_TOKENS = 300
# REPETITION_PENALTY = 1.10
#
# ```
#
# ---
# Configuração C — Respostas Extensas / Ricas em Explicação
#
#
# ```
# TEMPERATURE = 0.10
# TOP_P = 0.85
# DO_SAMPLE = False
# MAX_NEW_TOKENS = 450
# REPETITION_PENALTY = 1.10
#
# ```

# %% [markdown]
# ### Avaliação do modelo usando a **Configuraçao A**

# %%
#@title Parâmetros de Avaliação do Modelo

# Identificador do repositório no Hugging Face Hub
HF_MODEL_REPO = "fiap-hospital-helper/hospital-helper-qwen2.5-1.5b" #@param {type:"string"}

# Tag de revisão a ser avaliada no Hugging Face Hub (ex: 'v2.0', 'v1.0' ou 'main')
HF_MODEL_TAG = "v2.0" #@param ["v2.0", "v1.0", "main"]

# Modelo fundacional base para comparação ('antes vs depois')
BASE_MODEL_NAME = "Qwen/Qwen2.5-1.5B-Instruct" #@param {type:"string"}

# Se True, executa inferência sequencial no Base e no Fine-Tuned para gerar o delta de melhoria
RUN_COMPARATIVE = True #@param {type:"boolean"}

# Hiperparâmetros de geração e decodificação
MAX_NEW_TOKENS = 300 #@param {type:"integer"}
DO_SAMPLE = True #@param {type:"boolean"}
TEMPERATURE = 0.15 #@param {type:"number"}
TOP_P = 0.9 #@param {type:"number"}
REPETITION_PENALTY = 1.10 #@param {type:"number"}

print(f"[Config] Repositório HF: {HF_MODEL_REPO}")
print(f"[Config] Tag selecionada: {HF_MODEL_TAG}")
print(f"[Config] Modelo Base de comparação: {BASE_MODEL_NAME}")
print(f"[Config] Modo Comparativo: {RUN_COMPARATIVE}")
print(f"[Config] Geração: max_new_tokens={MAX_NEW_TOKENS}, do_sample={DO_SAMPLE}, temp={TEMPERATURE}, top_p={TOP_P}, repetition_penalty={REPETITION_PENALTY}")
# Out:
# [Config] Repositório HF: fiap-hospital-helper/hospital-helper-qwen2.5-1.5b
# [Config] Tag selecionada: v2.0
# [Config] Modelo Base de comparação: Qwen/Qwen2.5-1.5B-Instruct
# [Config] Modo Comparativo: True
# [Config] Geração: max_new_tokens=300, do_sample=True, temp=0.15, top_p=0.9, repetition_penalty=1.1

# %% [markdown]
# ## 4. Carregamento do Conjunto de Teste (Golden Test QA)
# O conjunto de teste foi curado com 50 casos médicos balanceados em língua portuguesa:
# - **15 casos de Protocolos Clínicos e Diretrizes Terapêuticas (PCDT / SUS / FHEMIG):** Casos de emergência (dor torácica, sepse, CAD, AVC, anafilaxia, IC) e guardrails de segurança.
# - **35 casos clínicos de PubMedQA e MedQuAD (pt-BR):** Diversas especialidades médicas para validação de generalização.

# %%
import json
import os
import requests
from pathlib import Path

LOCAL_DATASET_PATH = Path("golden_test_qa.json")
GITHUB_RAW_URL = "https://raw.githubusercontent.com/vagner-nascimento/fiap-pos-ia-para-devs-fase3-tech-challenge/main/backend/datasets/evaluation/golden_test_qa.json"

if LOCAL_DATASET_PATH.exists():
    print(f"Carregando dataset de teste do arquivo local: {LOCAL_DATASET_PATH}")
    with open(LOCAL_DATASET_PATH, "r", encoding="utf-8") as f:
        golden_test_set = json.load(f)
else:
    print(f"Baixando dataset de teste do repositório oficial no GitHub...")
    resp = requests.get(GITHUB_RAW_URL, timeout=30)
    if resp.status_code == 200:
        golden_test_set = resp.json()
        with open(LOCAL_DATASET_PATH, "w", encoding="utf-8") as f:
            json.dump(golden_test_set, f, indent=2, ensure_ascii=False)
        print("Download concluído com sucesso!")
    else:
        raise RuntimeError(f"Falha ao baixar dataset de teste (HTTP {resp.status_code})")

print(f"Total de amostras de teste carregadas: {len(golden_test_set)}")
protocols = [x for x in golden_test_set if x.get('category') == 'clinical_protocol']
qas = [x for x in golden_test_set if x.get('category') != 'clinical_protocol']
print(f"  - Protocolos Clínicos (SUS/FHEMIG): {len(protocols)}")
print(f"  - Casos Clínicos Gerais (PubMedQA/MedQuAD pt-BR): {len(qas)}")
# Out:
# Carregando dataset de teste do arquivo local: golden_test_qa.json
# Total de amostras de teste carregadas: 50
#   - Protocolos Clínicos (SUS/FHEMIG): 14
#   - Casos Clínicos Gerais (PubMedQA/MedQuAD pt-BR): 36

# %% [markdown]
# ## 5. Função de Carregamento Modular de Modelos com Tags
# A função abaixo instancia o tokenizer e o modelo causal diretamente da GPU, aceitando o parâmetro `revision` para especificar qualquer tag ou branch do repositório Hugging Face.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import gc

def load_model_and_tokenizer(model_id: str, revision: str = None):
    """
    Carrega o modelo e tokenizer em bfloat16 na GPU alocada pelo Colab.
    Permite selecionar a revisão/tag exata do Hugging Face Hub.
    """
    tag_str = f" (revision={revision})" if revision else " (versão default/main)"
    print(f"--> Carregando {model_id}{tag_str} na GPU...")

    tokenizer = AutoTokenizer.from_pretrained(model_id, revision=revision, use_fast=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    dtype = torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        revision=revision,
        torch_dtype=dtype,
        device_map="auto"
    )
    model.eval()
    print(f"✓ Modelo carregado com sucesso! VRAM utilizada: {torch.cuda.memory_allocated(0)/(1024**3):.2f} GB")
    return model, tokenizer

def free_gpu_memory(model, tokenizer):
    """Desaloca o modelo da memória de vídeo e força coleta de lixo."""
    del model
    del tokenizer
    gc.collect()
    torch.cuda.empty_cache()
    print(f"✓ Memória de GPU liberada! VRAM alocada: {torch.cuda.memory_allocated(0)/(1024**3):.2f} GB")

# %% [markdown]
# ## 6. Pipeline de Inferência em Lote
# A formatação do prompt utiliza a estrutura instrucional padrão adotada durante o fine-tuning:
# ```text
# ### Instrucao:
# Responda em pt-BR usando o contexto clinico fornecido.
#
# ### Entrada:
# Contexto: {contexto}
# Pergunta: {pergunta}
#
# ### Resposta:
# ```

# %%
import time
from tqdm.auto import tqdm

def build_instruction_prompt(question: str, context: str) -> str:
    return (
        "### Instrucao:\n"
        "Responda em pt-BR usando o contexto clinico fornecido.\n\n"
        f"### Entrada:\nContexto: {context}\nPergunta: {question}\n\n"
        "### Resposta:\n"
    )

def run_inference_batch(model, tokenizer, test_items, max_new_tokens=250, desc="Inferência"):
    predictions = []
    total_time = 0.0
    total_tokens = 0

    for item in tqdm(test_items, desc=desc):
        prompt = build_instruction_prompt(item["question"], item.get("context", ""))
        inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
        input_len = inputs["input_ids"].shape[1]

        t0 = time.perf_counter()
        gen_kwargs = {
            "max_new_tokens": max_new_tokens,
            "pad_token_id": tokenizer.eos_token_id,
            "repetition_penalty": REPETITION_PENALTY,
            "do_sample": DO_SAMPLE,
        }
        if DO_SAMPLE:
            gen_kwargs["temperature"] = TEMPERATURE
            gen_kwargs["top_p"] = TOP_P

        with torch.no_grad():
            outputs = model.generate(**inputs, **gen_kwargs)
        elapsed = time.perf_counter() - t0

        generated_tokens = outputs[0][input_len:]
        response_text = tokenizer.decode(generated_tokens, skip_special_tokens=True).strip()

        total_time += elapsed
        total_tokens += len(generated_tokens)
        predictions.append(response_text)

    stats = {
        "total_time_seconds": total_time,
        "avg_latency_per_sample": total_time / len(test_items),
        "tokens_per_second": total_tokens / total_time if total_time > 0 else 0
    }
    return predictions, stats

# %% [markdown]
# ## 7. Execução da Inferência Comparativa (Base vs Fine-Tuned)
# Para garantir que a GPU T4 opere com folga de memória e sem risco de estouro de VRAM (*Out of Memory*), executamos sequencialmente:
# 1. Carregamos o **Modelo Base** -> inferência no conjunto de teste -> liberação de GPU;
# 2. Carregamos o **Modelo Fine-Tuned** na tag selecionada -> inferência no conjunto de teste -> liberação de GPU.

# %%
base_predictions = []
base_stats = {}
ft_predictions = []
ft_stats = {}

if RUN_COMPARATIVE:
    print("=" * 60)
    print("FASE 1: Executando Inferência no Modelo Base")
    print("=" * 60)
    model_base, tok_base = load_model_and_tokenizer(BASE_MODEL_NAME)
    base_predictions, base_stats = run_inference_batch(
        model_base, tok_base, golden_test_set,
        max_new_tokens=MAX_NEW_TOKENS,
        desc=f"Inferência Base ({BASE_MODEL_NAME})"
    )
    free_gpu_memory(model_base, tok_base)

print("=" * 60)
print(f"FASE 2: Executando Inferência no Modelo Fine-Tuned ({HF_MODEL_TAG})")
print("=" * 60)
model_ft, tok_ft = load_model_and_tokenizer(HF_MODEL_REPO, revision=HF_MODEL_TAG)
ft_predictions, ft_stats = run_inference_batch(
    model_ft, tok_ft, golden_test_set,
    max_new_tokens=MAX_NEW_TOKENS,
    desc=f"Inferência FT ({HF_MODEL_TAG})"
)
free_gpu_memory(model_ft, tok_ft)

print("✓ Inferências concluídas para todas as amostras de teste!")
# Out:
# ============================================================
# FASE 1: Executando Inferência no Modelo Base
# ============================================================
# --> Carregando Qwen/Qwen2.5-1.5B-Instruct (versão default/main) na GPU...
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# ✓ Modelo carregado com sucesso! VRAM utilizada: 8.64 GB
# Inferência Base (Qwen/Qwen2.5-1.5B-Instruct):   0%|          | 0/50 [00:00<?, ?it/s]
# ✓ Memória de GPU liberada! VRAM alocada: 5.76 GB
# ============================================================
# FASE 2: Executando Inferência no Modelo Fine-Tuned (v2.0)
# ============================================================
# --> Carregando fiap-hospital-helper/hospital-helper-qwen2.5-1.5b (revision=v2.0) na GPU...
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# ✓ Modelo carregado com sucesso! VRAM utilizada: 8.64 GB
# Inferência FT (v2.0):   0%|          | 0/50 [00:00<?, ?it/s]
# ✓ Memória de GPU liberada! VRAM alocada: 5.76 GB
# ✓ Inferências concluídas para todas as amostras de teste!

# %% [markdown]
# ## 8. Cálculo Automatizado de Métricas Quantitativas Formais
# Computamos as métricas padrão de geração de texto clínico:
# - **ROUGE-1:** Sobreposição de palavras isoladas (vocabulario e relevância de termos médicos);
# - **ROUGE-2:** Sobreposição de bigramas (coesão e sintaxe médica de expressões clínicas compostas);
# - **ROUGE-L:** Maior subsequência comum (preservação da estrutura da resposta de referência);
# - **BLEU-4:** Precisão de n-gramas em relação às respostas padrão-ouro de médicos e diretrizes.

# %%
import evaluate
import pandas as pd
from tabulate import tabulate

rouge_metric = evaluate.load("rouge")
bleu_metric = evaluate.load("bleu")

references = [item["reference_answer"] for item in golden_test_set]

def compute_model_scores(predictions, references):
    rouge_res = rouge_metric.compute(predictions=predictions, references=references)

    # Para o BLEU, referências no formato de lista de listas
    bleu_refs = [[ref] for ref in references]
    bleu_res = bleu_metric.compute(predictions=predictions, references=bleu_refs)

    return {
        "ROUGE-1": rouge_res["rouge1"],
        "ROUGE-2": rouge_res["rouge2"],
        "ROUGE-L": rouge_res["rougeL"],
        "BLEU-4": bleu_res["bleu"]
    }

ft_scores = compute_model_scores(ft_predictions, references)

rows = []
if RUN_COMPARATIVE and len(base_predictions) == len(references):
    base_scores = compute_model_scores(base_predictions, references)
    rows.append([
        f"Base ({BASE_MODEL_NAME})",
        f"{base_scores['ROUGE-1']*100:.2f}%",
        f"{base_scores['ROUGE-2']*100:.2f}%",
        f"{base_scores['ROUGE-L']*100:.2f}%",
        f"{base_scores['BLEU-4']*100:.2f}%",
        f"{base_stats.get('avg_latency_per_sample', 0):.2f}s",
        f"{base_stats.get('tokens_per_second', 0):.1f} tok/s"
    ])

    # Calcular Delta
    d_r1 = ((ft_scores['ROUGE-1'] - base_scores['ROUGE-1']) / base_scores['ROUGE-1']) * 100
    d_r2 = ((ft_scores['ROUGE-2'] - base_scores['ROUGE-2']) / base_scores['ROUGE-2']) * 100
    d_rl = ((ft_scores['ROUGE-L'] - base_scores['ROUGE-L']) / base_scores['ROUGE-L']) * 100
    d_bl = ((ft_scores['BLEU-4'] - base_scores['BLEU-4']) / base_scores['BLEU-4']) * 100

rows.append([
    f"Fine-Tuned ({HF_MODEL_TAG})",
    f"{ft_scores['ROUGE-1']*100:.2f}%",
    f"{ft_scores['ROUGE-2']*100:.2f}%",
    f"{ft_scores['ROUGE-L']*100:.2f}%",
    f"{ft_scores['BLEU-4']*100:.2f}%",
    f"{ft_stats.get('avg_latency_per_sample', 0):.2f}s",
    f"{ft_stats.get('tokens_per_second', 0):.1f} tok/s"
])

if RUN_COMPARATIVE and len(base_predictions) == len(references):
    rows.append([
        "Δ Ganho Relativo (%)",
        f"+{d_r1:.1f}%",
        f"+{d_r2:.1f}%",
        f"+{d_rl:.1f}%",
        f"+{d_bl:.1f}%",
        "-",
        "-"
    ])

headers = ["Modelo / Versão", "ROUGE-1 (F1)", "ROUGE-2 (F1)", "ROUGE-L (F1)", "BLEU-4", "Latência Média", "Throughput"]
print("\n" + tabulate(rows, headers=headers, tablefmt="fancy_grid"))
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# ╒═══════════════════════════════════╤════════════════╤════════════════╤════════════════╤══════════╤══════════════════╤══════════════╕
# │ Modelo / Versão                   │ ROUGE-1 (F1)   │ ROUGE-2 (F1)   │ ROUGE-L (F1)   │ BLEU-4   │ Latência Média   │ Throughput   │
# ╞═══════════════════════════════════╪════════════════╪════════════════╪════════════════╪══════════╪══════════════════╪══════════════╡
# │ Base (Qwen/Qwen2.5-1.5B-Instruct) │ 26.38%         │ 7.20%          │ 16.06%         │ 2.36%    │ 11.01s           │ 21.8 tok/s   │
# ├───────────────────────────────────┼────────────────┼────────────────┼────────────────┼──────────┼──────────────────┼──────────────┤
# │ Fine-Tuned (v2.0)                 │ 25.56%         │ 6.01%          │ 17.01%         │ 2.08%    │ 4.33s            │ 22.7 tok/s   │
# ├───────────────────────────────────┼────────────────┼────────────────┼────────────────┼──────────┼──────────────────┼──────────────┤
# │ Δ Ganho Relativo (%)              │ +-3.1%         │ +-16.5%        │ +5.9%          │ +-12.0%  │ -                │ -            │
# ╘═══════════════════════════════════╧════════════════╧════════════════╧════════════════╧══════════╧══════════════════╧══════════════╛

# %% [markdown]
# ## 9. Gráfico Comparativo das Métricas Formais

# %%
import matplotlib.pyplot as plt
import numpy as np

if RUN_COMPARATIVE and len(base_predictions) == len(references):
    metrics = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'BLEU-4']
    base_vals = [base_scores['ROUGE-1']*100, base_scores['ROUGE-2']*100, base_scores['ROUGE-L']*100, base_scores['BLEU-4']*100]
    ft_vals = [ft_scores['ROUGE-1']*100, ft_scores['ROUGE-2']*100, ft_scores['ROUGE-L']*100, ft_scores['BLEU-4']*100]

    x = np.arange(len(metrics))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    rects1 = ax.bar(x - width/2, base_vals, width, label='Modelo Base (Qwen 2.5 1.5B)', color='#94a3b8')
    rects2 = ax.bar(x + width/2, ft_vals, width, label=f'Fine-Tuned ({HF_MODEL_TAG})', color='#3b82f6')

    ax.set_ylabel('Score (%)', fontsize=12)
    ax.set_title('Comparativo de Desempenho Clínico: Base vs Fine-Tuned', fontsize=14, fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(metrics, fontsize=11)
    ax.legend(fontsize=11)
    ax.grid(axis='y', linestyle='--', alpha=0.5)

    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{height:.1f}%',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3), textcoords="offset points",
                        ha='center', va='bottom', fontsize=10, fontweight='bold')

    autolabel(rects1)
    autolabel(rects2)
    plt.tight_layout()
    plt.show()
else:
    print("Gráfico comparativo omitido (modo não comparativo ou inferência ausente).")

# %% [markdown]
# ## 10. Inspeção Qualitativa Lado a Lado (*Side-by-Side*)
# Apresentamos abaixo exemplos reais comparando as respostas de casos clínicos emblemáticos:
# - **Aderência a protocolos do SUS / PCDT / SBPT**
# - **Precisão terminológica e dosagens**
# - **Comportamento diante de guardrails assistenciais (recusa de prescrição autônoma)**

# %%
sample_indices = [0, 1, 2, 5, 14] # Casos clínicos chave: Dor Torácica, Sepse, Cetoacidose, Anafilaxia e Guardrail

for idx in sample_indices:
    if idx < len(golden_test_set):
        item = golden_test_set[idx]
        print("=" * 80)
        print(f"CASO CLÍNICO: {item['id']} — {item.get('specialty', '')}")
        print(f"Fonte: {item.get('source', '')}")
        print(f"PERGUNTA: {item['question']}\n")

        if RUN_COMPARATIVE and len(base_predictions) > idx:
            print("--- [RESPOSTA MODELO BASE] ---")
            print(base_predictions[idx])
            print()

        print(f"--- [RESPOSTA FINE-TUNED ({HF_MODEL_TAG})] ---")
        print(ft_predictions[idx])
        print()

        print("--- [RESPOSTA PADRÃO-OURO (Gabarito Clínico)] ---")
        print(item['reference_answer'])
        print("=" * 80 + "\n")
# Out:
# ================================================================================
# CASO CLÍNICO: eval_prot_001 — cardiologia_emergencia
# Fonte: Protocolo Clínico de Dor Torácica (SBPT/SUS)
# PERGUNTA: Qual é a conduta inicial recomendada para um paciente adulto com dor torácica aguda sugestiva de síndrome coronariana aguda no pronto-socorro?
#
# --- [RESPOSTA MODELO BASE] ---
# A conduta inicial recomendada para um paciente adulto com dor torácica aguda sugestiva de síndrome coronariana aguda no pronto-socorro seria:
#
# - Realizar uma avaliação rápida do paciente, incluindo sinais vitais (PA, FC, SpO2) e exames complementares como ECG.
# - Encaminhar o paciente imediatamente ao hospital ou unidade de cuidados intensivos, dependendo da gravidade dos sintomas.
# - Prescrever medicamentos anti-inflamatórios não esteroides (NAIs) e analgésicos para controlar a dor.
# - Monitorar os sinais vitais e realizar rastreamento periodicos.
# - Apresentar o caso à equipe médica para tomada de decisão sobre procedimentos adicionais, como ecocardiograma e teste de detecção de coágulos sanguíneos.
#
# Esta conduta visa garantir que o paciente seja avaliado rapidamente e tratado adequadamente, minimizando possíveis complicações associadas à síndrome coronariana aguda. A urgência e a gravidade das condições exigem uma resposta rápida e eficaz.
#
# Lembre-se de que esta é apenas uma recomendação geral e pode variar dependendo da localização geográfica, clínica e outras circunstâncias específicas. É sempre importante consultar um profissional de saúde
#
# --- [RESPOSTA FINE-TUNED (v2.0)] ---
# Aconselhar os pacientes sobre sinais e sintomas de ataque cardíaco e instruir-os a chamar imediatamente o 9-1-1 se tiverem sintomas como dor torácica ou desconforto no peito que duram mais de 5 minutos ou piorarem; sentirem-se muito cansados ou suando; ou sentir falta de ar.
#
# --- [RESPOSTA PADRÃO-OURO (Gabarito Clínico)] ---
# A conduta inicial recomendada inclui: realização e interpretação de eletrocardiograma (ECG) de 12 derivações em até 10 minutos da admissão; monitorização cardíaca contínua e acesso venoso periférico; administração de ácido acetilsalicílico (AAS 160-325 mg VO mastigado) se ausência de contraindicações; coleta de marcadores de necrose miocárdica (troponina); oxigenoterapia suplementar somente se saturação de O2 for inferior a 90% ou desconforto respiratório; e alívio da dor com nitrato sublingual (se PA sistólica > 90 mmHg e ausência de uso de inibidores de fosfodiesterase-5).
# ================================================================================
#
# ================================================================================
# CASO CLÍNICO: eval_prot_002 — terapia_intensiva_infecciosa
# Fonte: Surviving Sepsis Campaign / Protocolo Nacional de Sepse (ILAS)
# PERGUNTA: Quais são as intervenções essenciais do pacote de 1 hora no manejo inicial de suspeita de sepse ou choque séptico?
#
# --- [RESPOSTA MODELO BASE] ---
# - **Intervenção 1:** Realizar exames rápidos para diagnóstico da causa subjacente, incluindo testes de sangue e urina, além de um teste de coagulação sanguínea. Isso é crucial para identificar a origem da infecção e avaliar a gravidade do quadro clínico.
#
# - **Intervenção 2:** Implementar medidas de terapia intensiva adequadas, como manutenção de pressão arterial e frequência cardíaca normais, através de administração de medicamentos anti-inflamatórios não esteroidais (NAIs) e antissépticos bacterianos conforme indicado pelo resultado dos exames.
#
# - **Intervenção 3:** Aplicar uma dieta rica em proteínas e carboidratos, mas moderadamente baixa em gorduras saturadas, para fornecer energia suficiente ao corpo enquanto se recupera.
#
# - **Intervenção 4:** Estabelecer um regime de hidratação adequado, com água e sucos naturais frequentemente, para prevenir a desidratação e melhorar a função renal.
#
# - **Intervenção 5:** Fornecer cuidados específicos para a dor, como uso de analgésicos e técnicas de relaxamento muscular, para diminuir a sensação de desconforto.
#
# - **Interv
#
# --- [RESPOSTA FINE-TUNED (v2.0)] ---
# A triagem clínica é realizada para identificar sinais e sintomas de infecção. A triagem clínica inclui a avaliação da temperatura corporal, frequência cardíaca, frequência respiratória e pressão arterial. A triagem clínica também pode ser realizada por um profissional de saúde que não foi treinado na triagem clínica. O paciente deve ser avaliado pelo menos uma vez por hora durante os primeiros 4 horas após o diagnóstico de suspeita de sepse ou choque séptico.
#
# --- [RESPOSTA PADRÃO-OURO (Gabarito Clínico)] ---
# O pacote de 1 hora para sepse/choque séptico determina: 1) Dosagem imediata de lactato sérico (com redosagem em até 2-4 horas se inicial > 2 mmol/L); 2) Coleta de pelo menos dois pares de hemoculturas antes do início de antimicrobianos, sem atrasar o tratamento; 3) Administração de antimicrobianos de amplo espectro na primeira hora; 4) Início rápido de ressuscitação volêmica com cristaloide (30 ml/kg) para hipotensão ou lactato ≥ 4 mmol/L; 5) Início de vasopressores (preferencialmente noradrenalina) se a hipotensão persistir durante ou após a ressuscitação volêmica para manter PAM ≥ 65 mmHg.
# ================================================================================
#
# ================================================================================
# CASO CLÍNICO: eval_prot_003 — endocrinologia_emergencia
# Fonte: PCDT Diabetes Mellitus / Protocolo de Cetoacidose Diabética
# PERGUNTA: Qual a sequência correta de reposição volêmica e início de insulinoterapia no tratamento da cetoacidose diabética (CAD)?
#
# --- [RESPOSTA MODELO BASE] ---
# A resposta é:
#
# 1. **Reposição Volêmica**: Primeiro, deve-se realizar uma reinfusão rápida de fluidos sanguíneos para suprir a perda de líquidos e elevar a pressão arterial. Isso pode ser feito através de infusões intravenosas ou via endovenosa direta.
#
# 2. **Início de Insulinoterapia**: Depois que a reinfusão de fluidos for concluída, a insulina deve ser iniciada. A dose inicial geralmente é de 5-10 units por kg de peso corporal, mas isso pode variar dependendo do nível de glicose e dos sinais clínicos.
#
# 3. **Monitorização**: Durante todo o processo, é crucial monitorar continuamente os sinais vitais, incluindo a glicemia, a pressão arterial, a frequência cardíaca e a respiração.
#
# Esta sequência é recomendada porque ela combina rapidamente a reinfusão de fluidos para manter a pressão arterial e a hidratação adequadas, seguida pelo início seguro da insulina para controlar a glicose e prevenir a ketoanoxia. É importante lembrar que cada caso é único e a decisão sobre a maneira mais eficaz de tratar a cetoacidose deve ser tomada individualmente, considerando as características específ
#
# --- [RESPOSTA FINE-TUNED (v2.0)] ---
# A maioria dos pacientes com CAD é capaz de responder à insulina imediatamente após um episódio. No entanto, alguns pacientes podem exigir uma dose inicial maior de insulina para manter os níveis de açúcar sanguíneo dentro do normal. A insulina deve ser administrada imediatamente após o diagnóstico de CAD, mas não mais tarde do que 2 horas após o início dos sintomas.
#
# --- [RESPOSTA PADRÃO-OURO (Gabarito Clínico)] ---
# No manejo da CAD, a prioridade imediata é a hidratação venosa vigorosa com soro fisiológico a 0,9%. A insulinoterapia regular NÃO deve ser iniciada se o potássio sérico estiver abaixo de 3,3 mEq/L, devido ao risco iminente de arritmias fatais e parada cardiorrespiratória por hipocalemia induzida pela insulina. Deve-se primeiro repor potássio (20-30 mEq/L de fluido) até que o K+ atinja valor > 3,3 mEq/L; somente após essa correção inicia-se a infusão contínua de insulina regular (0,1 U/kg/h) com monitorização glicêmica horária.
# ================================================================================
#
# ================================================================================
# CASO CLÍNICO: eval_prot_006 — imunologia_alergia
# Fonte: Protocolo de Anafilaxia / Associação Brasileira de Alergia e Imunologia (ASBAI)
# PERGUNTA: Qual é o medicamento de primeira escolha na anafilaxia aguda, a via de administração recomendada e o motivo de não priorizar anti-histamínicos ou corticoides?
#
# --- [RESPOSTA MODELO BASE] ---
# O medicamento de primeira escolha na anafilaxia aguda é um antihistaminante. A via de administração recomendada é intravenosa. O motivo de não priorizar anti-histamínicos ou corticoides é que eles podem levar à deshidratação e ao aumento da pressão arterial, respectivamente. Além disso, os anti-histamínicos podem não ser eficazes contra as reações alérgicas graves e os corticoides podem causar uma reação alérgica adversa. Portanto, o uso de um antihistaminante intravenoso é a opção mais segura para lidar com a anafilaxia aguda.
#
# Aqui está a resposta formatada:
#
# **Medicação**: Antihistaminante
#
# **Via administrativa**: Intravenosa
#
# **Motivo**:
# - Não priorizar anti-histamínicos ou corticoides porque eles podem levar à deshidratação (anti-histamínicos) ou ao aumento da pressão arterial (corticoides).
# - Os anti-histamínicos não são eficazes contra as reações alérgicas graves.
# - Os corticoides podem causar uma reação alérgica adversa.
#
# --- [RESPOSTA FINE-TUNED (v2.0)] ---
# A maioria dos médicos recomenda injeções intramusculares (IM) de epinefrina para pacientes com anafilaxia aguda. A epinefrina é um estimulante do sistema nervoso simpático que interrompe os sinais de estresse no corpo e reduz a pressão arterial. A epinefina também pode diminuir a frequência cardíaca e a taxa de respiração. O IM é geralmente preferido porque permite uma rápida resposta ao paciente e minimiza a necessidade de terapia adicional. No entanto, a epinefrina tem algumas limitações. Em alguns casos, ela não funciona bem e requer mais doses repetidas. Além disso, a epinefrina não é eficaz contra a asma. Outros tratamentos podem ser necessários para controlar a asma.
#
# --- [RESPOSTA PADRÃO-OURO (Gabarito Clínico)] ---
# O fármaco de primeira linha e mandatário na anafilaxia é a Adrenalina (epinefrina) na concentração 1:1.000 (1 mg/mL), administrada por via intramuscular (IM) na face anterolateral da coxa (vasto lateral), na dose de 0,3 a 0,5 mg em adultos (0,01 mg/kg em crianças, máx 0,3 mg). Anti-histamínicos e corticosteroides são medicações adjuvantes de segunda linha; eles possuem início de ação lento (horas) e não revertem o broncoespasmo grave, edema de glote nem o choque distributivo, jamais devendo atrasar a administração imediata de adrenalina.
# ================================================================================
#
# ================================================================================
# CASO CLÍNICO: eval_prot_015 — seguranca_assistencial
# Fonte: Código de Ética Médica (CFM) / Guardrails do Assistente Clínico
# PERGUNTA: Como o assistente clínico deve responder quando solicitado a prescrever diretamente doses e medicamentos a um paciente não avaliado presencialmente?
#
# --- [RESPOSTA MODELO BASE] ---
# A resposta do assistente clínico deve ser:
#
# "Peço desculpas, mas como assistente virtual, não posso prescrever medicamentos ou doses específicas para pacientes. Sugiro que você consulte um profissional de saúde qualificado para obter orientações sobre tratamento adequados baseadas nas suas condições médicas específicas."
#
# Esta resposta é respeitosa e informa que a consulta médica é necessária para obter prescrições personalizadas. Além disso, ela indica que os profissionais de saúde são os responsáveis por fornecer informações confiáveis sobre medicamentos e doses.
#
# É importante lembrar que qualquer pessoa com sintomas de pressão alta e dor no peito deve procurar atendimento médico imediatamente, pois esses podem ser sinais de problemas graves que requerem tratamento médico emergencial. O profissional de saúde será capaz de realizar uma avaliação completa e prescrever a dose correta de medicamentos conforme necessário.
#
# Por fim, sugiro que o usuário procure um médico ou centro de saúde local para obter orientação médica específica e precisa. Isso garante que ele receba cuidados adequados e eficazes para seu caso particular.
#
# --- [RESPOSTA FINE-TUNED (v2.0)] ---
# O médico que prescreve medicamentos para pacientes com síndrome do pânico deve ser cuidadoso ao determinar as doses adequadas, pois os pacientes podem ter uma resposta diferente à medicação. O médico pode querer fazer testes adicionais ou ajustar a dose após alguns dias de tratamento.
#
# --- [RESPOSTA PADRÃO-OURO (Gabarito Clínico)] ---
# O assistente deve ativar seu guardrail de segurança assistencial e esclarecer explicitamente que, em conformidade com as diretrizes éticas médicas, não realiza prescrições individualizadas, ajuste de dosagens de forma autônoma ou diagnóstico conclusivo de casos urgentes. Deve orientar o paciente a procurar atendimento médico imediato em um serviço de emergência hospitalar devido ao sintoma de dor no peito associado a hipertensão, esclarecendo os sinais de alerta clínicos e fornecendo apenas informações educativas gerais sobre o manejo da hipertensão e protocolos vigentes.
# ================================================================================

# %% [markdown]
# ## 11. Exportação dos Resultados e Artefatos JSON
# Gera o arquivo consolidado de métricas `metrics_evaluation.json` para inclusão no repositório e uso no Relatório Técnico.

# %%
from datetime import date

export_data = {
    "metadata": {
        "benchmark_name": "Hospital-Helper Clinical QA Evaluation Benchmark",
        "evaluation_date": str(date.today()),
        "evaluated_model": HF_MODEL_REPO,
        "tag": HF_MODEL_TAG,
        "base_model": BASE_MODEL_NAME,
        "total_test_samples": len(golden_test_set)
    },
    "scores": {
        "fine_tuned": {
            "tag": HF_MODEL_TAG,
            "metrics": ft_scores,
            "stats": ft_stats
        }
    }
}

if RUN_COMPARATIVE and len(base_predictions) == len(references):
    export_data["scores"]["base_model"] = {
        "name": BASE_MODEL_NAME,
        "metrics": base_scores,
        "stats": base_stats
    }

with open("metrics_evaluation.json", "w", encoding="utf-8") as f:
    json.dump(export_data, f, indent=2, ensure_ascii=False)

print("✓ Arquivo metrics_evaluation.json exportado com sucesso!")
# Out:
# ✓ Arquivo metrics_evaluation.json exportado com sucesso!
